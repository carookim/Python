# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
print(wine_quality)

# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets 
  
# metadata 
print(wine_quality.metadata) 
  
# variable information 
print(wine_quality.variables)
# Out:
# {'data': {'ids': None, 'features':       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
y.value_counts()
# 5,6등급의 와인데이터가 많다. 데이터가 몰려있다.
# Out:
# quality
# 6          2836
# 5          2138
# 7          1079
# 4           216
# 8           193
# 3            30
# 9             5
# Name: count, dtype: int64

# %%
# 1. 기본 모델 생성하기
# 학습용 데이터 / 테스트용 데이터 분류
# 학습
# 평가 .score() , 정확도(accuracy)

# 2. 모델 생성하기(잘 나올 때까지 생성 - 평가 반복)
# 각종 시각화를 통해 컬럼의 특성을 파악
# 학습용 컬럼을 선정
# 전처리
# 학습
# 평가 .score() , 정확도(accuracy)

# %%
# 학생풀이
# 어떤 기능을 하는 인공지능?

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo

# 데이터 가져오기
wine_quality = fetch_ucirepo(id=186)

# wine_quality에서 features 가져오기
X = wine_quality.data.features   # 이미 DataFrame 형태
# wine_quality에서 target 가져오기
y = pd.DataFrame(wine_quality.data.targets, columns=['quality'])

# 합치기
df = pd.concat([X, y], axis=1)

# 확인
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...
