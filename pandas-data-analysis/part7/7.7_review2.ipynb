# %% [markdown]
# #### K-Means k-평균 - 비지도 학습 - 군집(Cluster)
# ```
# 초기 중심점 설정 (Centroid)
# 데이터 할당 (Assignment)
# 중심점 업데이트 (Update)
# ```

# %%
import numpy as np
fruits = np.load('C:/김지은/파이썬_src/pandas-data-analysis/part7/data/fruits_300.npy')
fruits.shape # 이미지 100 x 100
# Out:
# (300, 100, 100)

# %%
import matplotlib.pyplot as plt
plt.imshow(fruits[1],cmap='gray')
plt.show()
