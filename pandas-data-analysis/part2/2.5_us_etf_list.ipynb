# %%
# %pip install beautifulsoup4 requests
# 서로 의존관계를 파악해서 맞는 버전으로 설치
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 라이브러리 불러오기
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
# 크롤링 가능여부 확인
import urllib.robotparser

rp = urllib.robotparser.RobotFileParser()
rp.set_url('https://news.naver.com/robots.txt')
rp.read()

url = 'https://news.naver.com/'
print(rp.can_fetch('*', url))  # True/False 반환
# Out:
# False

# %%
# 위키피디아 미국 ETF 웹 페이지에서 필요한 정보를 스크래핑하여 딕셔너리 형태로 변수 etfs에 저장
# 크롤링 정책중에 User Agent Plicy가 있으면 header 정보를 추가하면 가능
# 크롤링하던 사이트 뒤에 robot.txt 입력 접속을 통해 크롤링 가능여부를 확인할 수 있다.
url = "https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'lxml')   
rows = soup.select('div > ul > li')

print("resp: ", resp)
print("=" * 100)
print("resp.text: ", resp.text)
print("=" * 100)
print("soup: ", soup)
print("=" * 100)
print("rows: ", rows[50:55])
# Out:
# resp:  <Response [403]>
# ...
# resp.text:  Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also T400119.
#
# ...
# soup:  <html><body><p>Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also T400119.
# </p></body></html>
# ...
# rows:  []

# %%
etfs = {}
for row in rows:
    
    try:
        etf_name = re.findall("(.+?)\s\(", row.text)
        etf_market = re.findall("\((.+?):", row.text)
        etf_ticker = re.findall(":\s(.+)\)", row.text)
        
        if (len(etf_ticker) > 0) & (len(etf_market) > 0) & (len(etf_name) > 0):
            etfs[etf_ticker[0]] = [etf_market[0], etf_name[0]]

    except AttributeError as err:
        pass    

# etfs 딕셔너리 출력
print(etfs)
# Out:
# {}
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\('
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\('
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_11540\1232222225.py:5: SyntaxWarning: invalid escape sequence '\s'
#   etf_name = re.findall("(.+?)\s\(", row.text)
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_11540\1232222225.py:6: SyntaxWarning: invalid escape sequence '\('
#   etf_market = re.findall("\((.+?):", row.text)
# C:\Users\Playdata2\AppData\Local\Temp\ipykernel_11540\1232222225.py:7: SyntaxWarning: invalid escape sequence '\s'
#   etf_ticker = re.findall(":\s(.+)\)", row.text)

# %%
# etfs 딕셔너리를 데이터프레임으로 변환
df = pd.DataFrame(etfs)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
